# %% [markdown]
# <img src="./img/logo_UTN.svg" align="right" width="300" />
#
# # Trabajo Semanal 7 - Teoría de Circuitos 2
# ### Autor: Santiago Palozzo

# %% [markdown]
# # 1. Ejercicio 2 de la Guia TP5
#
# ![image.png](attachment:image.png)
#
# ## 1.1 Desarrollos en papel
#
# Se realizo la transformada Z a las transferencias de los filtro originales Butterworth para conseguir su correlato en el dominio digital.

# %%
from IPython.display import IFrame
IFrame("./desarrollo1.pdf", width=800, height=800)
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="./desarrollo1.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # 1.2 Simulacion numérica en Python

# %%
#%% Inicializacion de librerias
# Librerías externas NumPy, SciPy y Matplotlib
import scipy.signal as sig
import matplotlib.pyplot as plt
import numpy as np

# Librería de TC2
import pytc2.sistemas_lineales as tc2

#%% Inicializacion de graficos para el Notebook
plt.figure(1)
plt.close(1)

import matplotlib as mpl

fig_sz_x = 13
fig_sz_y = 7
fig_dpi = 80 # dpi
fig_font_size = 16

mpl.rcParams['figure.figsize'] = (fig_sz_x, fig_sz_y)
mpl.rcParams['figure.dpi'] = fig_dpi
plt.rcParams.update({'font.size':fig_font_size})
#%%  Fin - Inicialización de librerías

def gen_analog_butter(n, fc, btype, frequency_ax, print_tf=False):
    
    num_butt, den_butt= sig.butter(n, fc, btype, analog=True)
    tf_analog_butter= sig.TransferFunction(num_butt, den_butt)
    
    if print_tf:
        #tc2.pretty_print_lti(num_butt, den_butt)
        print(tf_analog_butter)

    wa, ha= sig.freqs(num_butt, den_butt, frequency_ax)
    
    tf_parameters= [tf_analog_butter, wa, ha]
    
    return tf_parameters

def mod_phase_h(h):

    mod= np.abs(h)
    phase= np.angle(h)
    
    return mod, phase;

def bodeCompareAnalogDigital(wa, h_analog, wd, h_digital, fc, numfig):
    
    fig_bode= plt.figure(numfig)
    ax_mod, ax_phase= fig_bode.subplots(2, 1, sharex=True)

    mod_a, phase_a= mod_phase_h(h_analog)
    mod_d, phase_d= mod_phase_h(h_digital)   

    # MODULE
    fig_bode.sca(ax_mod)
    ax_mod.plot(wa,20*np.log10(mod_a), label='Butter Analogico N=2')
    ax_mod.plot(wd,20*np.log10(mod_d), label='Butter Digital N=2', linestyle='--')
    ax_mod.set(xscale='log')
    plt.legend()
    plt.grid(True, which='both', axis='both')
    plt.ylabel('Magnitude [dB]')
    plt.title('Magnitude response')
    plt.axvline(fc, color='green', linestyle='--') # cutoff frequency
    
    # PHASE
    fig_bode.sca(ax_phase)
    ax_phase.plot(wa,phase_a, label='Butter Analogico N=2')
    ax_phase.plot(wd,phase_d, label='Butter Digital N=2',linestyle='--')
    ax_phase.set(xscale='log')
    plt.legend()
    plt.grid(True, which='both', axis='both')
    plt.xlabel('Angular frequency [rad/sec]')
    plt.ylabel('Phase [rad]')
    plt.title('Phase response')
    plt.axvline(fc, color='green', linestyle='--') # cutoff frequency
    
    plt.show()
    
#       return 0;

# %% [markdown]
# ## A) Pasabajos Butterworth a fs = 100 kHz

# %%
n= 2
fc= 1000
norma_fc= 1
fc_norm= fc/norma_fc
fs= 100e3
freq_lp= np.linspace(fc_norm/(10), fc_norm*10, 100000)

# Genero el filtro Butter analogico

analog_butter_lp= gen_analog_butter(n, fc_norm, "low", freq_lp)

#### Butter Digital

# Parametros
w0= 2*np.pi*fc_norm
k= 2*fs
Q= 1/np.sqrt(2)

# Filtro
num_butt_digital= [w0**2, 2 * w0**2, w0**2]
den_butt_digital= [k**2+(k*w0/Q)+w0**2, (2*w0**2)-(2*k**2), k**2-(k*w0/Q)+w0**2]

tf_digital_butter= sig.TransferFunction(num_butt_digital, den_butt_digital)
#tc2.pretty_print_lti(num_butt_digital, den_butt_digital)
wd,hd= sig.freqz(num_butt_digital, den_butt_digital, worN= freq_lp, fs=fs)


bodeCompareAnalogDigital(analog_butter_lp[1], analog_butter_lp[2], wd, hd, fc= fc_norm, numfig= 1)

# %% [markdown]
# ## B) Pasabajos Butterworth a fs = 10 kHz

# %%
fs= 10e3
# Genero el filtro Butter analogico
analog_butter_lp= gen_analog_butter(n, fc_norm, "low", freq_lp)

#### Butter Digital
# Parametros
w0= 2*np.pi*fc_norm
k= 2*fs
Q= 1/np.sqrt(2)

# Filtro
num_butt_digital= [w0**2, 2 * w0**2, w0**2]
den_butt_digital= [k**2+(k*w0/Q)+w0**2, (2*w0**2)-(2*k**2), k**2-(k*w0/Q)+w0**2]

tf_digital_butter= sig.TransferFunction(num_butt_digital, den_butt_digital)
#tc2.pretty_print_lti(num_butt_digital, den_butt_digital)
wd,hd= sig.freqz(num_butt_digital, den_butt_digital, worN= freq_lp, fs=fs)

bodeCompareAnalogDigital(analog_butter_lp[1], analog_butter_lp[2], wd, hd, fc= fc_norm, numfig= 1)

# %% [markdown]
# ## C.1)Pasaaltos Butterworth a fs = 100 kHz

# %%
fs= 100e3
fc_hp= 6e3
norma_hp= 1
fc_norm_hp= fc_hp/norma_hp
freq_hp= np.linspace(fc_norm_hp/10, fc_norm_hp*10, 100000)


# Genero el filtro Butter analogico
analog_butter_hp= gen_analog_butter(n, fc_norm_hp, "high", freq_hp)


#### Butter Digital
# Parametros
w0= 2*np.pi*fc_norm_hp
k= 2*fs
Q= 1/np.sqrt(2)

# Filtro
num_butt_digital= [k**2, -2 * k**2, k**2]
den_butt_digital= [k**2+(k*w0/Q)+w0**2, (2*w0**2)-(2*k**2), k**2-(k*w0/Q)+w0**2]

tf_digital_butter= sig.TransferFunction(num_butt_digital, den_butt_digital)
#tc2.pretty_print_lti(num_butt_digital, den_butt_digital)
wd,hd= sig.freqz(num_butt_digital, den_butt_digital, worN= freq_hp, fs=fs)

bodeCompareAnalogDigital(analog_butter_hp[1], analog_butter_hp[2], wd, hd, fc= fc_norm_hp, numfig= 2)

# %% [markdown]
# ## C.2)Pasaaltos Butterworth a fs = 10 kHz

# %%
fs= 10e3

# Genero el filtro Butter analogico
analog_butter_hp= gen_analog_butter(n, fc_norm_hp, "high", freq_hp, True)


#### Butter Digital
# Parametros
w0= 2*np.pi*fc_norm_hp
k= 2*fs
Q= 1/np.sqrt(2)

# Filtro
num_butt_digital= [k**2, -2 * k**2, k**2]
den_butt_digital= [k**2+(k*w0/Q)+w0**2, (2*w0**2)-(2*k**2), k**2-(k*w0/Q)+w0**2]

tf_digital_butter= sig.TransferFunction(num_butt_digital, den_butt_digital)
#tc2.pretty_print_lti(num_butt_digital, den_butt_digital)
wd,hd= sig.freqz(num_butt_digital, den_butt_digital, worN= freq_hp, fs=fs)

bodeCompareAnalogDigital(analog_butter_hp[1], analog_butter_hp[2], wd, hd, fc= fc_norm_hp, numfig= 2)
# Out:
# TransferFunctionContinuous(
# array([1., 0., 0.]),
# array([1.00000000e+00, 8.48528137e+03, 3.60000000e+07]),
# dt: None
# )
# C:\Users\santi\AppData\Local\Temp\ipykernel_12188\2914179870.py:59: RuntimeWarning: divide by zero encountered in log10
#   ax_mod.plot(wd,20*np.log10(mod_d), label='Butter Digital N=2', linestyle='--')

# %% [markdown]
# ## D) Rediseño aplicando prewarping
#
# El caso que podria rediseñarse es el C) principalmente, ya que en este se observa como ante un cambio en la fs la transferencia deteriora sus características. Esto se debe a que ahora la fc del filtro pasaaltos es superior a la frecuencia de Nyquist, esto es fs/2. Se podria modificar la constante k de modo que la respuesta en frecuencia del fitlro se sintonice a 6kHz a expensas de alinealidades en el resto de la transfrerencia.

# %% [markdown]
# # 2. Ejercicio 3 de la Guia TP5
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 2.1 Desarrollo en papel

# %%
from IPython.display import IFrame
IFrame("./desarrollo2.pdf", width=800, height=800)
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="./desarrollo2.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 2.2 Respuestas a las preguntas de la consigna
#
# A.1) Este filtro se conoce como promediador. La suma de todas las entradas (actual y anteriores) del filtro queda afectada por los coeficientes $b_n$ del filtro. Si estos coeficientes son iguales y su valor es $b_n = \frac{1}{N}$ siendo N el orden del filtro más 1, la salida del sistema será la media arimetica.
#
# A.2) Para eliminar la interferencia causada por la frecuencia de linea 50 Hz la frecuencia de corte del filtro debe ser inferior a los 50Hz. Por ejemplo, tomando $f_c= 40 Hz$, la frecuencia de muestreo para lograr filtrar correctamente debería ser según Nyquist, como mínimo, el doble. Entonces, seria necesaria una frecuencia de muestreo $f_{s_{min}}=80 Hz$
#
# B.1) En el calculo de fase se observa que el filtro de primer orden tendrá un retardo de media cuenta, mientras que el de segundo orden tendrá una cuenta de demora. Esto es conveniente ya que en el contexto de un sistema digital, un retardo de media cuenta cae justo en el medio de cualquier cuantizacion que pueda requerir el proceso.
#
# B.2) Estos sistemas actuan como un derivador ideal hasta una frecuencia $f_{ideal}=0,31 \cdot f_s$ (ver desarrollo en papel)

# %% [markdown]
# # 3. Ejercicio de la TS7
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3.1 Desarrollo en papel

# %%
from IPython.display import IFrame
IFrame("./desarrollo3.pdf", width=800, height=800)
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="./desarrollo3.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
