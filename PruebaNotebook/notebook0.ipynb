# %% [markdown]
# # <img src="./logo_UTN.svg" align="right" width="300" />
#
# #### Teoría de los Circuitos 2
#
# # Mi Primer Notebook - Trabajo Semanal 0
# #### Autor: Santiago Palozzo

# %% [markdown]
# ***
# # 0. Introducción
#
# Este notebook servirá de prueba para las futuras entregas durante el año. Voy a ver las distintas sintaxis de *Markdown* y para las pruebas con codigo se hará uso a modo de ejemplo del script **demo_seg_orden1.py**.

# %% [markdown]
# ***
# # 1. Markdown
#
# Citas:
# > *Esta es una cita de prueba*
#
# Viñetas:
#
# - Punto1
#     - Punto2
#     - Punto3
#
# Markdown Cheatsheet: [link](https://ingeh.medium.com/markdown-for-jupyter-notebooks-cheatsheet-386c05aeebed)

# %% [markdown]
# ***
# # 2. Bloques de código
# Primero, debo incluir las librerias correspondientes para que el script funcione.

# %%
# PyTC2: La librería para TC2
from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot

# Librerías externas NumPy, SciPy y Matplotlib
from scipy.signal import TransferFunction
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Luego fijamos el estilo de los gráficos en el notebook (*no es parte del script de python*).

# %%
# Esta parte de código la agregamos SOLO en los notebooks para fijar el estilo de los gráficos.

#%%  Inicialización de librerías (esto NO es parte del script demo_seg_orden1.py)
# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del jupyter notebook documento

# algún bug cuando lo hice:
plt.figure(1)
plt.close(1)

import matplotlib as mpl

fig_sz_x = 13
fig_sz_y = 7
fig_dpi = 80 # dpi
fig_font_size = 16

mpl.rcParams['figure.figsize'] = (fig_sz_x, fig_sz_y)
mpl.rcParams['figure.dpi'] = fig_dpi
plt.rcParams.update({'font.size':fig_font_size})

#%%  Fin - Inicialización de librerías

# %% [markdown]
# Ahora, incluyo el codigo del ejemplo. La ecuacion que representa este sistema es:
#
# \begin{equation}
# H(s) = \frac{\omega_0^2}{s^2 + \frac{\omega_0}{Q}s + \omega_0^2}
# \end{equation}
#
#
# Reemplazo los valores originales por $\omega_0 = 0.5$ y $Q = 25$

# %%
# Valores originales:
# w0 = 1
# qq = np.sqrt(2)/2

w0 = 0.5
qq = 25

my_tf = TransferFunction( [w0**2], [1, w0/qq, w0**2] )

bodePlot(my_tf, fig_id=1, filter_description = 'Q={:3.3f}'.format(qq) )

pzmap(my_tf, fig_id=2, filter_description = 'Q={:3.3f}'.format(qq)) #S plane pole/zero plot

GroupDelay(my_tf, fig_id=3, filter_description = 'Q={:3.3f}'.format(qq))
# Out:
# (3,
#  <Axes: title={'center': 'Group delay'}, xlabel='Angular frequency [rad/sec]', ylabel='Group Delay [sec]'>)

# %% [markdown]
# ***
# # 3. Conclusiones
# La verdad solo conocia esta herramienta de nombre, no sabia que era lo que hacia. Me parece una muy buena forma de implementar el codigo interactivamente en un documento, te facilita incluir los graficos por ejemplo que ya los incluye desde los scripts.
#
# Mientras que lo iba editando me fui encontrando con errores o cosas que quería hacer y no sabia por qué no me aparecía bien (sin ir mas lejos, pasar a otro párrafo). Creo que vino bien de cara a la entrega de los TPs ya que me encontre con esas dificultades ahora en vez de más adelante.
#
# <img src="tux.jpg" title="Tux" align="center" width="200"/>
