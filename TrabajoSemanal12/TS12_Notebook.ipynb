# %% [markdown]
# <img src="./img/logo_UTN.svg" align="right" width="300" />
#
# # Trabajo Semanal 12 - Teoría de Circuitos 2
# ### Autor: Santiago Palozzo
#
# ![image.png](attachment:f38de1b4-bca5-41c7-9207-5a0ab3b37402.png)
#
# ![image.png](attachment:bda441e0-f01d-4c31-a462-1cdc7f4627f4.png)

# %% [markdown]
# # 1. Desarrollo en papel

# %%
from IPython.display import IFrame
IFrame("./desarrollo.pdf", width=1000, height=800)
# Out:
#         <iframe
#             width="1000"
#             height="800"
#             src="./desarrollo.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # 2. Simulacion simbólica en Python
#
# ## Ejercicio 1

# %%
#%% Inicializacion de librerias
# Librerías externas NumPy, SymPy y Matplotlib
import sympy as sp
import matplotlib.pyplot as plt
import numpy as np

# Librería de TC2
import pytc2 as tc2

# %% [markdown]
# ## Ejercicio 2

# %% [markdown]
# # 3. Simulación circuital en LTspice
#
# ## Ejercicio 1
#
#
# ## Ejercicio 2
