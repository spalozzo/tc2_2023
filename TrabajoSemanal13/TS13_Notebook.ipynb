# %% [markdown]
# <img src="./img/logo_UTN.svg" align="right" width="300" />
#
# # Trabajo Semanal 12 - Teoría de Circuitos 2
# ### Autor: Santiago Palozzo
#
# Diseñar el cuadripolo A de forma que sea:
# - Filtro pasa bajos Bessel de 3er. orden
# - No disipativo
# - Normalizado en frecuencia e impedancia
#
# ![image.png](attachment:3963a164-2d2f-4871-9334-1dd2eae575c6.png)

# %% [markdown]
# # 1. Desarrollo en papel

# %%
from IPython.display import IFrame
IFrame("./desarrollo.pdf", width=1000, height=800)
# Out:
#         <iframe
#             width="1000"
#             height="800"
#             src="./desarrollo.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # 2. Simulación circuital en LTspice
#
# ## Simulacion normalizada
#
# ![image.png](attachment:de6c9890-bacb-4d92-934b-f570962f994c.png)
#
# ### Grafico de S11
#
# ![image.png](attachment:95fb786d-9e7d-47aa-9685-04762098b64e.png)
#
# ### Grafico de S21
#
# ![image.png](attachment:dda0fe00-c585-49b1-8c71-ab0753e10ed6.png)
#
# ## Simulacion desnormalizada
#
# ![image.png](attachment:233fbca6-5c96-4f42-b16f-2ae67444290c.png)

# %% [markdown]
# # Conclusiones
# ![image.png](attachment:9420784d-a200-4872-8de2-0ae754ea68aa.png)
#
# Analizando el gráfico de S11 en funcion de la frecuencia, se observa que toma su menor valor cuando el filtro se encuentra en la banda de paso. En dicha zona, el filtro deja pasar la mayor cantidad de energia al puerto de salida, por lo que es logico que el coeficiente de reflexion en la entrada sea minimo. Luego de la transicion entre la banda de paso y la banda detenida donde S11 toma valores intermedios, llega a su mayor valor en la banda de stop. Esto se explica ya que en esta zona, el filtro atenuara todas las componentes de frecuencia que ve a la entrada y, por lo tanto, las disipa en dicho puerto. Es por esto que el coeficiente de reflexion sera maximo, transmitiendo la menor energia a la salida.
