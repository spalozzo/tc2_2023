# %% [markdown]
# <img src="./img/logo_UTN.svg" align="right" width="300" />
#
# # Trabajo Semanal 4 bis - Teoría de Circuitos 2
# ### Autor: Santiago Palozzo
#
# <img src="./img/consigna.png" align="center" width="600" />

# %% [markdown]
# # 1. Desarrollo en papel

# %%
from IPython.display import IFrame
IFrame("./desarrollo.pdf", width=800, height=800)
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="./desarrollo.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # 2. Simulacion numérica en Python

# %%
#%% Inicializacion de librerias
# Librerías externas NumPy, SciPy y Matplotlib
import scipy.signal as sig
import matplotlib.pyplot as plt
import numpy as np

# Librería de TC2
import pytc2.sistemas_lineales as tc2

# %%
#%% Inicializacion de graficos para el Notebook
plt.figure(1)
plt.close(1)

import matplotlib as mpl

fig_sz_x = 13
fig_sz_y = 7
fig_dpi = 80 # dpi
fig_font_size = 16

mpl.rcParams['figure.figsize'] = (fig_sz_x, fig_sz_y)
mpl.rcParams['figure.dpi'] = fig_dpi
plt.rcParams.update({'font.size':fig_font_size})
#%%  Fin - Inicialización de librerías

# %%
#%%Defino los parametros de la plantilla
fs1= 1250
fs2= 3200
fci= 1600
fcs= 2500

alfa_max= 3     # dB, es un butter
alfa_min= 20    # dB, igual para ambas bandas de stop

ganancia= 10    # dB, en la banda de paso

ee2= 1
n= 3
Q_bp= 20/9  # Calculado en papel
Bw= 1/Q_bp  # w0= 1

#%% Consigo el pasabanda de una
print("- Prototipo Pasabajo Butterworth -")
print("Epsilon2= ",ee2)
print("Grado del filtro: ",n)

z, p, k= sig.buttap(n)
num_lp, den_lp= sig.zpk2tf(z, p, k)
print("\n Prototipo pasabajos Butterworth")
tc2.pretty_print_lti(num_lp, den_lp)

num_bp, den_bp= sig.lp2bp(num_lp, den_lp, bw = 1/Q_bp)
print("\n Transferencia pasabanda")
tc2.pretty_print_lti(num_bp, den_bp)

## Muestro la transferencia BP en secciones de 2do orden
print("\n Transferencia pasabanda factorizada en SOS")
sos_bp = tc2.tf2sos_analog(num_bp, den_bp)
tc2.pretty_print_SOS(sos_bp)

tf_bp =  sig.TransferFunction(num_bp, den_bp)
tc2.analyze_sys(tf_bp, sys_name='Pasabanda 2do orden')
# Out:
# - Prototipo Pasabajo Butterworth -
# Epsilon2=  1
# Grado del filtro:  3
#
#  Prototipo pasabajos Butterworth
# $\displaystyle \frac{  1 }{s^3 + s^2 \,\,   2 + s \,\,   2 +   1 }$
#  Transferencia pasabanda
# $\displaystyle \frac{s^3 \,\, 0.09112 }{s^6 + s^5 \,\, 0.9 + s^4 \,\, 3.405 + s^3 \,\, 1.891 + s^2 \,\, 3.405 + s \,\, 0.9 +   1 }$
#  Transferencia pasabanda factorizada en SOS
# $\displaystyle   \frac{s^2 \,\, 1.673 }{s^2 + s \,\, 0.45 +   1 } . \frac{s \,\, 0.2836 }{s^2 + s \,\, 0.2683 + 1.476 } . \frac{s \,\, 0.1921 }{s^2 + s \,\, 0.1817 + 0.6773 }$

# %% [markdown]
# # 3. Circuito normalizado y simulación en LTspice
#
# Esta implementacion se realizo con la topología Ackerberg-Mossberg. Para lograr el orden 6, se utilizaron 3 circuitos en cascada. Es importante notar que la simulacion se realizo de tal forma que en el eje X de LTspice $1 Hz$ coincide con lo que sería $1 \frac{rad}{s}$
#
# <img src="./img/circuito_spice.png" align="center" width="1200" />
#
# <img src="./img/simulacion_spice.png" align="center" width="1000" />

# %% [markdown]
# En el grafico se observa como en $\omega= 1$ hay una ganancia de 10db, mientras que en $\omega_{ci}= 0.8$ y $\omega_{cs}= 1.25$ la atenuacion es de 7 dB, es decir -3dB respecto de la banda de paso. Se observa que se cumplen las especificaciones del enunciado.
